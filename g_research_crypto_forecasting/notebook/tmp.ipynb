# %%
import os
import pathlib

import pandas as pd
import numpy as np

# %%
data_dir = pathlib.Path("../data")

# %%
train = pd.read_csv(
    data_dir / "raw/train.csv",
    dtype={
        "Asset_ID": np.int8,
        "Count": np.int32,
        "Open": np.float64,
        "High": np.float64,
        "Low": np.float64,
        "Close": np.float64,
        "Volume": np.float64,
        "VWAP": np.float64,
        "Target": np.float64,
    },
)
asset_details = pd.read_csv(data_dir / "raw/asset_details.csv")

display(train.head())
display(asset_details)
# Out:
#     timestamp  Asset_ID  Count        Open        High         Low  \
# 0  1514764860         2     40   2376.5800   2399.5000   2357.1400
# 1  1514764860         0      5      8.5300      8.5300      8.5300
# 2  1514764860         1    229  13835.1940  14013.8000  13666.1100
# 3  1514764860         5     32      7.6596      7.6596      7.6567
# 4  1514764860         7      5     25.9200     25.9200     25.8740
#
#         Close       Volume          VWAP    Target
# 0   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300    78.380000      8.530000 -0.014399
# 2  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8770   121.087310     25.891363 -0.008264
#     Asset_ID    Weight        Asset_Name
# 0          2  2.397895      Bitcoin Cash
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 3          5  1.386294            EOS.IO
# 4          7  2.079442  Ethereum Classic
# 5          6  5.894403          Ethereum
# 6          9  2.397895          Litecoin
# 7         11  1.609438            Monero
# 8         13  1.791759              TRON
# 9         12  2.079442           Stellar
# 10         3  4.406719           Cardano
# 11         8  1.098612              IOTA
# 12        10  1.098612             Maker
# 13         4  3.555348          Dogecoin

# %%
assetId_assetName = {row["Asset_ID"]: row["Asset_Name"] for _, row in asset_details[["Asset_ID", "Asset_Name"]].iterrows()}

# %%
train["Asset_Name"] = train["Asset_ID"].map(assetId_assetName)

# %%
out = train.pivot_table(
    index="timestamp", 
    columns="Asset_Name", 
    values=["Count", "Open", "High", "Low", "Close", "Volume", "VWAP"]
)

# %%
out.head()
# Out:
#                   Close                                                   \
# Asset_Name Binance Coin    Bitcoin Bitcoin Cash Cardano Dogecoin  EOS.IO
# timestamp
# 1514764860       8.5300  13850.176  2374.590000     NaN      NaN  7.6576
# 1514764920       8.5145  13828.102  2372.286667     NaN      NaN  7.6567
# 1514764980       8.4848  13801.314  2372.063333     NaN      NaN  7.6512
# 1514765040       8.5009  13768.040  2370.566667     NaN      NaN  7.6358
# 1514765100       8.4560  13724.914  2370.173333     NaN      NaN  7.6100
#
#                                                         ...   Volume  \
# Asset_Name  Ethereum Ethereum Classic IOTA    Litecoin  ... Dogecoin
# timestamp                                               ...
# 1514764860  738.5075          25.8770  NaN  225.206667  ...      NaN
# 1514764920  738.2600          25.8970  NaN  224.856667  ...      NaN
# 1514764980  737.5025          26.4695  NaN  226.000000  ...      NaN
# 1514765040  737.1025          26.4495  NaN  224.275000  ...      NaN
# 1514765100  735.7050          26.4370  NaN  223.820000  ...      NaN
#
#                                                                               \
# Asset_Name       EOS.IO    Ethereum Ethereum Classic IOTA     Litecoin Maker
# timestamp
# 1514764860  6626.713370  335.987856       121.087310  NaN   411.896642   NaN
# 1514764920  3277.475494  232.793141         1.468019  NaN  3640.502706   NaN
# 1514764980  5623.557585  174.138031        76.163922  NaN   328.350286   NaN
# 1514765040  1696.632459  165.383926       408.774848  NaN   507.405579   NaN
# 1514765100  2268.362218  193.078039       529.337600  NaN  1035.671830   NaN
#
#
# Asset_Name     Monero Stellar TRON
# timestamp
# 1514764860   6.635710     NaN  NaN
# 1514764920   0.349420     NaN  NaN
# 1514764980   1.189553     NaN  NaN
# 1514765040   1.512079     NaN  NaN
# 1514765100  11.997972     NaN  NaN
#
# [5 rows x 98 columns]

# %%
new_col_names = [f"{asset_name}_{col_name}" for col_name, asset_name in out.columns.tolist()]

# %%
out.columns = new_col_names

# %%
out = out.reindex(sorted(out.columns), axis=1)

# %%
out.head()
# Out:
#             Binance Coin_Close  Binance Coin_Count  Binance Coin_High  \
# timestamp
# 1514764860              8.5300                 5.0             8.5300
# 1514764920              8.5145                 7.0             8.5300
# 1514764980              8.4848                45.0             8.5299
# 1514765040              8.5009                14.0             8.5066
# 1514765100              8.4560                 5.0             8.5007
#
#             Binance Coin_Low  Binance Coin_Open  Binance Coin_VWAP  \
# timestamp
# 1514764860            8.5300             8.5300           8.530000
# 1514764920            8.5145             8.5300           8.520215
# 1514764980            8.4848             8.5065           8.501394
# 1514765040            8.4744             8.5009           8.479810
# 1514765100            8.4560             8.5007           8.458435
#
#             Binance Coin_Volume  Bitcoin Cash_Close  Bitcoin Cash_Count  \
# timestamp
# 1514764860                78.38         2374.590000                40.0
# 1514764920                71.39         2372.286667                53.0
# 1514764980              1546.82         2372.063333                61.0
# 1514765040               125.80         2370.566667                95.0
# 1514765100               125.01         2370.173333                33.0
#
#             Bitcoin Cash_High  ...  Stellar_Open  Stellar_VWAP  \
# timestamp                      ...
# 1514764860             2399.5  ...           NaN           NaN
# 1514764920             2400.9  ...           NaN           NaN
# 1514764980             2401.9  ...           NaN           NaN
# 1514765040             2406.4  ...           NaN           NaN
# 1514765100             2404.6  ...           NaN           NaN
#
#             Stellar_Volume  TRON_Close  TRON_Count  TRON_High  TRON_Low  \
# timestamp
# 1514764860             NaN         NaN         NaN        NaN       NaN
# 1514764920             NaN         NaN         NaN        NaN       NaN
# 1514764980             NaN         NaN         NaN        NaN       NaN
# 1514765040             NaN         NaN         NaN        NaN       NaN
# 1514765100             NaN         NaN         NaN        NaN       NaN
#
#             TRON_Open  TRON_VWAP  TRON_Volume
# timestamp
# 1514764860        NaN        NaN          NaN
# 1514764920        NaN        NaN          NaN
# 1514764980        NaN        NaN          NaN
# 1514765040        NaN        NaN          NaN
# 1514765100        NaN        NaN          NaN
#
# [5 rows x 98 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24236806 entries, 0 to 24236805
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   timestamp   int64
#  1   Asset_ID    int8
#  2   Count       int32
#  3   Open        float64
#  4   High        float64
#  5   Low         float64
#  6   Close       float64
#  7   Volume      float64
#  8   VWAP        float64
#  9   Target      float64
#  10  Asset_Name  object
# dtypes: float64(7), int32(1), int64(1), int8(1), object(1)
# memory usage: 1.7+ GB

# %%
for _, row in asset_details.sort_values(by="Asset_ID").iterrows():
    data = train[train["Asset_ID"] == row["Asset_ID"]]
    data = data.set_index("timestamp")
    data.dropna(subset=["Target"], axis=0, inplace=True)

    # Reindex to fill nan missing data(timestamp).
    # print(f"\n=== Asset Name is {row['Asset_Name']} ===")
    # data = data.reindex(range(data.index[0], data.index[-1] + 60, 60), method="pad")
    # split_data(data, asset_name=row["Asset_Name"])
# Out:
# === Asset Name is Binance Coin ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_50383/3967953827.py in <module>
#       8     print(f"\n=== Asset Name is {row['Asset_Name']} ===")
#       9     data = data.reindex(range(data.index[0], data.index[-1] + 60, 60), method="pad")
# ---> 10     split_data(data, asset_name=row["Asset_Name"])
#
# NameError: name 'split_data' is not defined
