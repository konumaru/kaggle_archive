# %% [markdown]
# # ~~XLM~~
#
# OOM になるので断念
#
# - Baseline:
# - dropout 0.3:
# - dropout 0.5:

# %%
import re
import pathlib

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import transformers
from sklearn.model_selection import KFold, StratifiedKFold
from pytorch_lightning import Trainer
from pytorch_lightning.loggers import TensorBoardLogger
from torch.utils.data import DataLoader, Dataset
from transformers import XLMTokenizer, XLMModel

from transformers import AutoConfig, AutoModelForSequenceClassification

# %%
src_dir = pathlib.Path("../data/raw")

# %% [markdown]
# ## Split Fold

# %%
data = pd.read_csv(src_dir / "train.csv")
target_bins = pd.cut(data["target"], bins=10, labels=False)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for n_fold, (train_idx, valid_idx) in enumerate(cv.split(data, target_bins)):

    train = data.loc[train_idx, ["excerpt", "target"]]
    valid = data.loc[valid_idx, ["excerpt", "target"]]

    fold_dump_dir = pathlib.Path(f"../data/split/fold_{n_fold}/")
    fold_dump_dir.mkdir(exist_ok=True)

    train.to_pickle(fold_dump_dir / "train.pkl")
    valid.to_pickle(fold_dump_dir / "valid.pkl")

    print("Fold:", n_fold)
    print(f"\tTrain Target Average: {train.target.mean():.06f}")
    print(f"\tValid Target Average: {valid.target.mean():.06f}")
# Out:
# Fold: 0
# 	Train Target Average: -0.959512
# 	Valid Target Average: -0.958545
# Fold: 1
# 	Train Target Average: -0.959406
# 	Valid Target Average: -0.958969
# Fold: 2
# 	Train Target Average: -0.960382
# 	Valid Target Average: -0.955068
# Fold: 3
# 	Train Target Average: -0.958762
# 	Valid Target Average: -0.961544
# Fold: 4
# 	Train Target Average: -0.958532
# 	Valid Target Average: -0.962472

# %% [markdown]
# ## Define Dataset & Dataloader

# %%
import pathlib
from typing import Optional

import numpy as np
import pandas as pd
import pytorch_lightning as pl
import torch
from torch.utils.data import DataLoader, Dataset


class CommonLitDataset(Dataset):
    def __init__(self, data, tokenizer, max_len=256):
        self.target = data[["target"]].to_numpy()
        self.excerpt = data[["excerpt"]].to_numpy()
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.excerpt)

    def __getitem__(self, idx):
        text = str(self.excerpt[idx])
        inputs = self.tokenizer(
            text,
            max_length=self.max_len,
            padding="max_length",
            truncation=True,
        )

        ids = inputs["input_ids"]
        mask = inputs["attention_mask"]

        target = self.target[idx]

        return {
            "input_ids": torch.tensor(ids, dtype=torch.long),
            "attention_mask": torch.tensor(mask, dtype=torch.long),
            "target": torch.tensor(target, dtype=torch.float32),
        }


class CommonLitDataModule(pl.LightningDataModule):
    def __init__(self, data_dir: str, tokenizer, batch_size: int = 32):
        super(CommonLitDataModule, self).__init__()
        self.data_dir = pathlib.Path(data_dir)
        self.tokenizer = tokenizer
        self.batch_size = batch_size

    def setup(self, stage: Optional[str] = None):
        self.train = pd.read_pickle(self.data_dir / "train.pkl")
        self.valid = pd.read_pickle(self.data_dir / "valid.pkl")

    def train_dataloader(self):
        dataset = CommonLitDataset(self.train, self.tokenizer)
        return DataLoader(
            dataset,
            batch_size=self.batch_size,
            num_workers=4,
            pin_memory=True,
            shuffle=True,
            drop_last=True,
        )

    def val_dataloader(self):
        dataset = CommonLitDataset(self.valid, self.tokenizer)
        return DataLoader(
            dataset,
            batch_size=self.batch_size,
            num_workers=4,
            pin_memory=True,
            shuffle=False,
            drop_last=False,
        )

    def test_dataloader(self):
        dataset = CommonLitDataset(self.valid, self.tokenizer)
        return DataLoader(
            dataset,
            batch_size=self.batch_size,
            num_workers=4,
            pin_memory=True,
            shuffle=False,
            drop_last=False,
        )

# %% [markdown]
# ## Define Model Arch

# %%
import pytorch_lightning as pl
import pytorch_warmup as warmup
import torch
import torch.nn as nn
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from transformers import (
    AdamW,
    AutoModelForSequenceClassification,
    AutoTokenizer,
    XLMRobertaModel,
    get_cosine_schedule_with_warmup,
    get_linear_schedule_with_warmup,
)


class RMSELoss(nn.Module):
    def __init__(self, eps=1e-6):
        super().__init__()
        self.mse = nn.MSELoss()
        self.eps = eps

    def forward(self, yhat, y):
        loss = torch.sqrt(self.mse(yhat, y) + self.eps)
        return loss
    

class CommonLitXLMModel(nn.Module):
    def __init__(self):
        super(CommonLitXLMModel, self).__init__()
        self.xlm = XLMModel.from_pretrained('xlm-mlm-en-2048')
        self.layers = nn.Sequential(
#             nn.Dropout(0.5),
            nn.Linear(2048, 1),
        )

    def forward(self, batch):
        ids = batch["input_ids"]
        mask = batch["attention_mask"]
        
        output = self.xlm(input_ids=ids, attention_mask=mask)
        output = output.last_hidden_state[:, 0, :]
        output = self.layers(output)
        return output
    
    
class CommonLitModel(pl.LightningModule):
    def __init__(
        self,
        num_epoch: int = 20,
        train_dataloader_len: int = 20,
        lr: float = 1e-4,
    ):
        super(CommonLitModel, self).__init__()
        self.lr = lr
        self.num_epoch = num_epoch
        self.train_dataloader_len = train_dataloader_len

        self.model = CommonLitXLMModel()
        self.loss_fn = nn.MSELoss()
        self.eval_fn = RMSELoss()

    def forward(self, batch):
        z = self.model(batch)
        return z

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(
            self.parameters(),
            lr=self.lr,
            betas=(0.9, 0.999),
            eps=1e-8,
            weight_decay=5e-2,
        )
        lr_scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=2,
            num_training_steps=self.train_dataloader_len * self.num_epoch,
        )
        return [optimizer], [lr_scheduler]

    def shared_step(self, batch):
        z = self(batch)
        loss = self.loss_fn(z, batch["target"])
        metric = self.eval_fn(z, batch["target"])
        return z, loss, metric

    def training_step(self, batch, batch_idx):
        z, loss, metric = self.shared_step(batch)
        self.log("train_loss", loss)
        return {"loss": loss}

    def validation_step(self, batch, batch_idx):
        z, loss, metric = self.shared_step(batch)
        self.log("val_loss", loss, prog_bar=True)
        self.log("val_metric", metric, prog_bar=True)
        return {"val_loss": loss, "val_metric": metric}

    def test_step(self, batch, batch_idx):
        z, loss, metric = self.shared_step(batch)
        return {"test_loss": loss, "test_metric": metric}

    def test_step_end(self, outputs):
        return outputs

    def test_epoch_end(self, outputs):
        loss = torch.cat([out["test_loss"] for out in outputs], dim=0)
        metric = torch.cat([out["test_metric"] for out in outputs], dim=0)
        self.log("test_loss", torch.mean(loss), "test_metric", torch.mean(metric))

# %% [markdown]
# ## Train Model

# %%
tokenizer = XLMTokenizer.from_pretrained('xlm-mlm-en-2048')

# %%
num_epoch = 100

best_checkpoints = []
for n_fold in range(5):
    datamodule = CommonLitDataModule(f"../data/split/fold_{n_fold}/", tokenizer, 32)
    datamodule.setup()

    # Logger
    tb_logger = TensorBoardLogger(
        save_dir="../tb_logs",
        name="Baseline",
    )
    # Callbacks
    lr_monitor = LearningRateMonitor(logging_interval="step")
    early_stop = EarlyStopping(
        mode="min",
        patience=20,
        verbose=False,
        monitor="val_loss",
        min_delta=0.01,
    )
    checkpoint = ModelCheckpoint(
        filename="{epoch:02d}-{loss:.4f}-{val_loss:.4f}",
        monitor="val_loss",
        mode="min",
    )

    train_dataloader_len = len(datamodule.train_dataloader())
    model = CommonLitModel(
        num_epoch=num_epoch,
        train_dataloader_len=train_dataloader_len,
    )
    trainer = Trainer(
        max_epochs=num_epoch,
        gpus=1,
        accelerator="dp",
        logger=tb_logger,
        callbacks=[lr_monitor, early_stop, checkpoint]
    )
    trainer.fit(model=model, datamodule=datamodule)
    trainer.test(model=model, datamodule=datamodule)
    
    best_checkpoints.append(checkpoint.best_model_path)
    torch.cuda.empty_cache()
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type              | Params
# ----------------------------------------------
# 0 | model   | CommonLitXLMModel | 667 M
# 1 | loss_fn | MSELoss           | 0
# 2 | eval_fn | RMSELoss          | 0
# ----------------------------------------------
# 667 M     Trainable params
# 0         Non-trainable params
# 667 M     Total params
# 2,668.364 Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-813c307c7c24> in <module>
#      38         callbacks=[lr_monitor, early_stop, checkpoint]
#      39     )
# ---> 40     trainer.fit(model=model, datamodule=datamodule)
#      41     trainer.test(model=model, datamodule=datamodule)
#      42
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloader, val_dataloaders, datamodule)
#     456         )
#     457
# --> 458         self._run(model)
#     459
#     460         assert self.state.stopped
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py in _run(self, model)
#     754
#     755         # dispatch `start_training` or `start_evaluating` or `start_predicting`
# --> 756         self.dispatch()
#     757
#     758         # plugin will finalized fitting (e.g. ddp_spawn will load trained model)
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py in dispatch(self)
#     795             self.accelerator.start_predicting(self)
#     796         else:
# --> 797             self.accelerator.start_training(self)
#     798
#     799     def run_stage(self):
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/accelerators/accelerator.py in start_training(self, trainer)
#      94
#      95     def start_training(self, trainer: 'pl.Trainer') -> None:
# ---> 96         self.training_type_plugin.start_training(trainer)
#      97
#      98     def start_evaluating(self, trainer: 'pl.Trainer') -> None:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in start_training(self, trainer)
#     142     def start_training(self, trainer: 'pl.Trainer') -> None:
#     143         # double dispatch to initiate the training loop
# --> 144         self._results = trainer.run_stage()
#     145
#     146     def start_evaluating(self, trainer: 'pl.Trainer') -> None:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py in run_stage(self)
#     805         if self.predicting:
#     806             return self.run_predict()
# --> 807         return self.run_train()
#     808
#     809     def _pre_training_routine(self):
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/trainer.py in run_train(self)
#     867                 with self.profiler.profile("run_training_epoch"):
#     868                     # run train epoch
# --> 869                     self.train_loop.run_training_epoch()
#     870
#     871                 if self.max_steps and self.max_steps <= self.global_step:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/training_loop.py in run_training_epoch(self)
#     488             # ------------------------------------
#     489             with self.trainer.profiler.profile("run_training_batch"):
# --> 490                 batch_output = self.run_training_batch(batch, batch_idx, dataloader_idx)
#     491
#     492             # when returning -1 from train_step, we end epoch early
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/training_loop.py in run_training_batch(self, batch, batch_idx, dataloader_idx)
#     729
#     730                         # optimizer step
# --> 731                         self.optimizer_step(optimizer, opt_idx, batch_idx, train_step_and_backward_closure)
#     732
#     733                     else:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/training_loop.py in optimizer_step(self, optimizer, opt_idx, batch_idx, train_step_and_backward_closure)
#     422
#     423         # model hook
# --> 424         model_ref.optimizer_step(
#     425             self.trainer.current_epoch,
#     426             batch_idx,
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/core/lightning.py in optimizer_step(self, epoch, batch_idx, optimizer, optimizer_idx, optimizer_closure, on_tpu, using_native_amp, using_lbfgs)
#    1401
#    1402         """
# -> 1403         optimizer.step(closure=optimizer_closure)
#    1404
#    1405     def optimizer_zero_grad(self, epoch: int, batch_idx: int, optimizer: Optimizer, optimizer_idx: int):
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/core/optimizer.py in step(self, closure, *args, **kwargs)
#     212             profiler_name = f"optimizer_step_and_closure_{self._optimizer_idx}"
#     213
# --> 214         self.__optimizer_step(*args, closure=closure, profiler_name=profiler_name, **kwargs)
#     215         self._total_optimizer_step_calls += 1
#     216
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/core/optimizer.py in __optimizer_step(self, closure, profiler_name, **kwargs)
#     132
#     133         with trainer.profiler.profile(profiler_name):
# --> 134             trainer.accelerator.optimizer_step(optimizer, self._optimizer_idx, lambda_closure=closure, **kwargs)
#     135
#     136     def step(self, *args, closure: Optional[Callable] = None, **kwargs):
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/accelerators/accelerator.py in optimizer_step(self, optimizer, opt_idx, lambda_closure, **kwargs)
#     327         )
#     328         if make_optimizer_step:
# --> 329             self.run_optimizer_step(optimizer, opt_idx, lambda_closure, **kwargs)
#     330         self.precision_plugin.post_optimizer_step(optimizer, opt_idx)
#     331         self.training_type_plugin.post_optimizer_step(optimizer, opt_idx, **kwargs)
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/accelerators/accelerator.py in run_optimizer_step(self, optimizer, optimizer_idx, lambda_closure, **kwargs)
#     334         self, optimizer: Optimizer, optimizer_idx: int, lambda_closure: Callable, **kwargs: Any
#     335     ) -> None:
# --> 336         self.training_type_plugin.optimizer_step(optimizer, lambda_closure=lambda_closure, **kwargs)
#     337
#     338     def optimizer_zero_grad(self, current_epoch: int, batch_idx: int, optimizer: Optimizer, opt_idx: int) -> None:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in optimizer_step(self, optimizer, lambda_closure, **kwargs)
#     191
#     192     def optimizer_step(self, optimizer: torch.optim.Optimizer, lambda_closure: Callable, **kwargs):
# --> 193         optimizer.step(closure=lambda_closure, **kwargs)
#     194
#     195     @property
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/optim/adamw.py in step(self, closure)
#      63         if closure is not None:
#      64             with torch.enable_grad():
# ---> 65                 loss = closure()
#      66
#      67         for group in self.param_groups:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/training_loop.py in train_step_and_backward_closure()
#     723
#     724                         def train_step_and_backward_closure():
# --> 725                             result = self.training_step_and_backward(
#     726                                 split_batch, batch_idx, opt_idx, optimizer, self.trainer.hiddens
#     727                             )
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/training_loop.py in training_step_and_backward(self, split_batch, batch_idx, opt_idx, optimizer, hiddens)
#     812         with self.trainer.profiler.profile("training_step_and_backward"):
#     813             # lightning module hook
# --> 814             result = self.training_step(split_batch, batch_idx, opt_idx, hiddens)
#     815             self._curr_step_result = result
#     816
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/trainer/training_loop.py in training_step(self, split_batch, batch_idx, opt_idx, hiddens)
#     278             model_ref._results = Result()
#     279             with self.trainer.profiler.profile("training_step"):
# --> 280                 training_step_output = self.trainer.accelerator.training_step(args)
#     281                 self.trainer.accelerator.post_training_step()
#     282
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/accelerators/accelerator.py in training_step(self, args)
#     202
#     203         with self.precision_plugin.train_step_context(), self.training_type_plugin.train_step_context():
# --> 204             return self.training_type_plugin.training_step(*args)
#     205
#     206     def post_training_step(self) -> None:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/plugins/training_type/dp.py in training_step(self, *args, **kwargs)
#      96
#      97     def training_step(self, *args, **kwargs):
# ---> 98         return self.model(*args, **kwargs)
#      99
#     100     def validation_step(self, *args, **kwargs):
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     163
#     164         if len(self.device_ids) == 1:
# --> 165             return self.module(*inputs[0], **kwargs[0])
#     166         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     167         outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/overrides/data_parallel.py in forward(self, *inputs, **kwargs)
#      75         self.update_replica_device_attributes(inputs)
#      76         # forward call will redirect to training_step, validation_step, etc.
# ---> 77         output = super().forward(*inputs, **kwargs)
#      78
#      79         def output_transform(data: Any):
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/pytorch_lightning/overrides/base.py in forward(self, *inputs, **kwargs)
#      44
#      45         if trainer and trainer.training:
# ---> 46             output = self.module.training_step(*inputs, **kwargs)
#      47
#      48             # In manual_optimization, we need to prevent DDP reducer as
#
# <ipython-input-5-3ac0c89b31d3> in training_step(self, batch, batch_idx)
#      87
#      88     def training_step(self, batch, batch_idx):
# ---> 89         z, loss, metric = self.shared_step(batch)
#      90         self.log("train_loss", loss)
#      91         return {"loss": loss}
#
# <ipython-input-5-3ac0c89b31d3> in shared_step(self, batch)
#      81
#      82     def shared_step(self, batch):
# ---> 83         z = self(batch)
#      84         loss = self.loss_fn(z, batch["target"])
#      85         metric = self.eval_fn(z, batch["target"])
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-5-3ac0c89b31d3> in forward(self, batch)
#      62
#      63     def forward(self, batch):
# ---> 64         z = self.model(batch)
#      65         return z
#      66
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-5-3ac0c89b31d3> in forward(self, batch)
#      39         mask = batch["attention_mask"]
#      40
# ---> 41         output = self.xlm(input_ids=ids, attention_mask=mask)
#      42         output = output.last_hidden_state[:, 0, :]
#      43         output = self.layers(output)
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/transformers/models/xlm/modeling_xlm.py in forward(self, input_ids, attention_mask, langs, token_type_ids, position_ids, lengths, cache, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     590
#     591             # self attention
# --> 592             attn_outputs = self.attentions[i](
#     593                 tensor,
#     594                 attn_mask,
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/transformers/models/xlm/modeling_xlm.py in forward(self, input, mask, kv, cache, head_mask, output_attentions)
#     170         if kv is None:
#     171             k = shape(self.k_lin(input))  # (bs, n_heads, qlen, dim_per_head)
# --> 172             v = shape(self.v_lin(input))  # (bs, n_heads, qlen, dim_per_head)
#     173         elif cache is None or self.layer_id not in cache:
#     174             k = v = kv
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~/commonLit_readability_prize/.venv/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# RuntimeError: CUDA out of memory. Tried to allocate 64.00 MiB (GPU 0; 15.78 GiB total capacity; 14.44 GiB already allocated; 12.75 MiB free; 14.48 GiB reserved in total by PyTorch)

# %% [markdown]
# ## CV Score

# %%
def calc_average_loss(ckeckpoints):
    metrics = []
    for ckpt in ckeckpoints:
        metric = float(re.findall(r"val_loss=(\d+\.\d+)", ckpt)[0])
        metrics.append(metric)
        
    return np.mean(metrics)

# %%
avg_valid_loss = calc_average_loss(best_checkpoints)
print("Average Validation Loss:", avg_valid_loss)
